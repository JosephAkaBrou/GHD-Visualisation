# %%
import pandas as pd

# %%
data = pd.read_csv('data2.csv')

# %%
data[(data.location =="Poland") & (data.sex == "Male") & (data.year == 2010)]
# Out:
#    measure location   sex       age          cause  metric  year          val  \
# 0   Deaths   Poland  Male  20 to 24  Road injuries  Number  2010   476.475277
# 2   Deaths   Poland  Male  25 to 29  Road injuries  Number  2010   404.630638
# 4   Deaths   Poland  Male  30 to 34  Road injuries  Number  2010   333.944110
# 6   Deaths   Poland  Male  35 to 39  Road injuries  Number  2010   298.177738
# 8   Deaths   Poland  Male  40 to 44  Road injuries  Number  2010   290.178068
# 10  Deaths   Poland  Male  45 to 49  Road injuries  Number  2010   335.073248
# 12  Deaths   Poland  Male  50 to 54  Road injuries  Number  2010   409.302025
# 14  Deaths   Poland  Male  55 to 59  Road injuries  Number  2010   361.584641
# 16  Deaths   Poland  Male  60 to 64  Road injuries  Number  2010   262.913923
# 18  Deaths   Poland  Male  65 to 69  Road injuries  Number  2010   149.397168
# 20  Deaths   Poland  Male  70 to 74  Road injuries  Number  2010   145.863186
# ...
